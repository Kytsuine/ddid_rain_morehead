# %%
import pandas as pd
import regex as re
import fuzzywuzzy
import numpy as np
import geopandas as gpd
from fuzzywuzzy import fuzz

# %%
aeps = pd.read_excel(
    "./data/AEPSi Data for NSS.xlsx",
    2,
    usecols=[
        "Child ID",
        "Program Name",
        "AEPSi ID",
        "AssessID",
        "Gender",
        "Dev Status",
        "AEPS Level",
        "DOB",
        "Test Date",
        "Examiner",
        "Service Coordinator",
        "TEIS Point of Entry Office (POE)",
        "ESL",
        "County of Residence",
        "Number of Items",
        "fm_B4.0",
        "fm_B5.0",
        "cog_D2.0",
        "cog_E2.0",
        "cog_E4.0",
        "cog_F1.0",
        "cog_G1.0",
        "cog_G2.0",
        "cog_G3.0",
        "cog_G4.0",
        "cog_G5.0",
        "cog_G6.0",
        "sc_B1.0",
        "sc_B2.0",
        "sc_D1.0",
        "sc_D2.0",
        "sc_D3.0",
        "FM Raw Score",
        "FM Possible Score",
        "FM Percentage",
        "Cog Raw Score",
        "Cog Possible Score",
        "Cog Percentage",
        "SC Raw Score",
        "SC Possible Score",
        "SC Percentage"], 
    parse_dates = False) ## Big tall ugly command cuts down columns to just the ones we might need. 
aeps.head()
# Out:
#   Child ID                                     Program Name  AEPSi ID  \
# 0       11                                   Signal Centers    722747
# 1    10724  Little Tennessee Valley Educational Cooperative    707878
# 2    10724  Little Tennessee Valley Educational Cooperative    707878
# 3    11112                                             SRVS    665041
# 4    11112                                             SRVS    665041
#
#    AssessID                  DOB Gender                Dev Status  AEPS Level  \
# 0  10584304  2020-02-02 00:00:00      M  Dev. Delay or Disability           1
# 1  10575064  2021-07-30 00:00:00      F  Dev. Delay or Disability           1
# 2  10589703  2021-07-30 00:00:00      F  Dev. Delay or Disability           1
# 3  10535282  2020-04-27 00:00:00      F  Dev. Delay or Disability           1
# 4  10503223  2020-04-27 00:00:00      F  Dev. Delay or Disability           1
#
#              Test Date                          Examiner  ... sc_D3.0  \
# 0  2022-04-21 00:00:00          Maria E. Vives-Rodriguez  ...     0.0
# 1  2022-03-01 00:00:00  Olivia J Woodall;Olivia Woodall   ...     0.0
# 2  2022-05-09 00:00:00   Olivia J Woodall;Olivia Woodall  ...     0.0
# 3  2021-07-08 00:00:00                     Beth Murphree  ...     0.0
# 4  2020-12-30 00:00:00                     Beth Murphree  ...     0.0
#
#   FM Raw Score FM Possible Score FM Percentage  Cog Raw Score  \
# 0         51.0              66.0        0.7727           65.0
# 1         19.0              66.0        0.2879           26.0
# 2         29.0              66.0        0.4394           41.0
# 3         41.0              66.0        0.6212           36.0
# 4         33.0              66.0        0.5000           18.0
#
#    Cog Possible Score  Cog Percentage  SC Raw Score  SC Possible Score  \
# 0               116.0          0.5603          52.0               92.0
# 1               116.0          0.2241          15.0               92.0
# 2               116.0          0.3534          24.0               92.0
# 3               116.0          0.3103          28.0               92.0
# 4               116.0          0.1552          18.0               92.0
#
#    SC Percentage
# 0         0.5652
# 1          0.163
# 2         0.2609
# 3         0.3043
# 4         0.1957
#
# [5 rows x 41 columns]

# %%
aeps_temp = aeps
#aeps = aeps_temp
#Use as needed in testing to avoid re-importing the excel sheet. Avoids long datetime conversion.

# %%
aeps = aeps.applymap(lambda x: x.strip() if isinstance(x, str) else x) ## Strips all strings in dataframe
aeps = aeps.drop(aeps.index[17926:17959]) ## Removes empty and illogical child id's at end of dataframe
aeps = aeps.drop([0, 7, 1393, 17774]) ## Removes a few more illogical child id's and one row full of null values
aeps = aeps.drop_duplicates(subset='AssessID') ## Removes duplicate assessment results
aeps['child_id'] = aeps['Child ID'].astype(int)
aeps['dob'] = pd.to_datetime(aeps['DOB'], errors='coerce') ## errors='coerce' causes errors to be entered as 'NaT'
aeps['test_date'] = pd.to_datetime(aeps['Test Date'], errors='coerce')
aeps['age_at_test'] = aeps['test_date'] - aeps['dob']
aeps['test_number'] = aeps.groupby('child_id').age_at_test.rank()
aeps['examiner'] = aeps['Examiner'].str.replace(
    r"\;.*",""
    ).str.replace(
    r",.*",""
    ).str.replace(
    r"\/.*",""
    ).str.replace(
    r"\:",""
    ).str.lower()
aeps.head()
# Out:
# /tmp/ipykernel_38946/1568236774.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   aeps['examiner'] = aeps['Examiner'].str.replace(
#   Child ID                                     Program Name  AEPSi ID  \
# 1    10724  Little Tennessee Valley Educational Cooperative    707878
# 2    10724  Little Tennessee Valley Educational Cooperative    707878
# 3    11112                                             SRVS    665041
# 4    11112                                             SRVS    665041
# 5    11112                                             SRVS    665041
#
#    AssessID                  DOB Gender                Dev Status  AEPS Level  \
# 1  10575064  2021-07-30 00:00:00      F  Dev. Delay or Disability           1
# 2  10589703  2021-07-30 00:00:00      F  Dev. Delay or Disability           1
# 3  10535282  2020-04-27 00:00:00      F  Dev. Delay or Disability           1
# 4  10503223  2020-04-27 00:00:00      F  Dev. Delay or Disability           1
# 5  10485665  2020-04-27 00:00:00      F  Dev. Delay or Disability           1
#
#              Test Date                         Examiner  ... Cog Percentage  \
# 1  2022-03-01 00:00:00  Olivia J Woodall;Olivia Woodall  ...         0.2241
# 2  2022-05-09 00:00:00  Olivia J Woodall;Olivia Woodall  ...         0.3534
# 3  2021-07-08 00:00:00                    Beth Murphree  ...         0.3103
# 4  2020-12-30 00:00:00                    Beth Murphree  ...         0.1552
# 5  2020-09-15 00:00:00                    Beth Murphree  ...         0.0776
#
#   SC Raw Score SC Possible Score SC Percentage  child_id        dob  \
# 1         15.0              92.0         0.163     10724 2021-07-30
# 2         24.0              92.0        0.2609     10724 2021-07-30
# 3         28.0              92.0        0.3043     11112 2020-04-27
# 4         18.0              92.0        0.1957     11112 2020-04-27
# 5          6.0              92.0        0.0652     11112 2020-04-27
#
#    test_date  age_at_test  test_number          examiner
# 1 2022-03-01     214 days          1.0  olivia j woodall
# 2 2022-05-09     283 days          2.0  olivia j woodall
# 3 2021-07-08     437 days          3.0     beth murphree
# 4 2020-12-30     247 days          2.0     beth murphree
# 5 2020-09-15     141 days          1.0     beth murphree
#
# [5 rows x 47 columns]

# %%
#Start just by taking a look at the column
aeps.examiner
# Out:
# 1         olivia j woodall
# 2         olivia j woodall
# 3            beth murphree
# 4            beth murphree
# 5            beth murphree
#                ...
# 17921       krystal prater
# 17922        doreen lawton
# 17923       krystal prater
# 17924    d'anitra reynolds
# 17925       ashley cordell
# Name: examiner, Length: 17762, dtype: object

# %%
#Look at the value counts for the column
aeps.examiner.value_counts()
# Out:
# jen johnson                 547
# karen julian                327
# janet dixon                 298
# kristen gilmartin talamo    239
# michele valadie             233
#                            ...
# jessica l mcbryar             1
# laura harerll                 1
# jessica beaver                1
# ciara olive2                  1
# marci hhopson                 1
# Name: examiner, Length: 674, dtype: int64

# %%
#First, an easy adjustment, stripping any leading or lagging spaces
aeps.examiner = aeps.examiner.str.strip()
aeps.examiner
# Out:
# 1         olivia j woodall
# 2         olivia j woodall
# 3            beth murphree
# 4            beth murphree
# 5            beth murphree
#                ...
# 17921       krystal prater
# 17922        doreen lawton
# 17923       krystal prater
# 17924    d'anitra reynolds
# 17925       ashley cordell
# Name: examiner, Length: 17762, dtype: object

# %%
#We do see a decent reduction in the number of unique values (as indicated here by the number of lengths)
aeps.examiner.value_counts()
# Out:
# jen johnson                 559
# karen julian                327
# janet dixon                 298
# kristen gilmartin talamo    239
# michele valadie             233
#                            ...
# hannah hamiltn                1
# kscott                        1
# jan apps                      1
# jennifer  cavitt              1
# marci hhopson                 1
# Name: examiner, Length: 653, dtype: int64

# %%
#Now we'll look for any cells that contain a semicolon and keep only what is to the left of the semicolon
aeps.examiner = aeps.examiner.str.extract('(^[^;]+)')
aeps.examiner
# Out:
# 1         olivia j woodall
# 2         olivia j woodall
# 3            beth murphree
# 4            beth murphree
# 5            beth murphree
#                ...
# 17921       krystal prater
# 17922        doreen lawton
# 17923       krystal prater
# 17924    d'anitra reynolds
# 17925       ashley cordell
# Name: examiner, Length: 17762, dtype: object

# %%
#This leads to another reduction in unique values
aeps.examiner.value_counts()
# Out:
# jen johnson                 559
# karen julian                327
# janet dixon                 298
# kristen gilmartin talamo    239
# michele valadie             233
#                            ...
# hannah hamiltn                1
# kscott                        1
# jan apps                      1
# jennifer  cavitt              1
# marci hhopson                 1
# Name: examiner, Length: 653, dtype: int64

# %%
#Making the value counts into a dataframe
ex_counts = aeps.examiner.value_counts().to_frame()
#Keeping only those entries that occur more than once
ex_counts = ex_counts.loc[ex_counts.examiner > 1]
#Turning that into a list
examiner_list =ex_counts.index.to_list()
examiner_list
# Out:
# ['jen johnson',
#  'karen julian',
#  'janet dixon',
#  'kristen gilmartin talamo',
#  'michele valadie',
#  'kandace haag',
#  'clayton rouse',
#  'hannah vantrease',
#  'traci wilber',
#  'aimee loeffler',
#  'larendi armstrong',
#  'david fosbinder',
#  'lori boles',
#  'esmeralda',
#  'shannon blakeman',
#  'molly morris',
#  'ashley cordell',
#  'marisa borreca',
#  'angel early',
#  'angie mccoy',
#  'teresa motley',
#  'laura harrell',
#  'camille crawford',
#  'gina wilson',
#  'barbara may',
#  'jennifer cavitt',
#  'leeann finnegan',
#  'sarah watkins',
#  'kristen gilmartin',
#  'hannah hamilton',
#  'sarah dugan',
#  'mallory sigler',
#  'laura riddell',
#  'leslie throneberry',
#  'morgan blake',
#  'diana barrick',
#  'patricia reese',
#  'amy trent',
#  'deanna stephens',
#  'michelle fox',
#  'cindy kennard',
#  'virginia martino',
#  'megan jones',
#  'rachel stewart',
#  'kristina scott',
#  'rosario langlois',
#  'karisha mcneal',
#  'jessie bradley',
#  'regina piercy',
#  'lisa ketner',
#  'jennifer long',
#  'britney mcconnell',
#  'kourtney daniels',
#  'melissa moore',
#  'jen choate',
#  'jamie carter',
#  'melonie kellner',
#  'jenn conley',
#  'beth murphree',
#  'rachel saine',
#  'casey winningham',
#  'lauren groth',
#  'georgia birchfield',
#  'jenny buchanan',
#  'allison carmack',
#  'rilee taylor',
#  'stephanie brown',
#  'gwen evans',
#  'wanda marchie',
#  'endia v. lewis',
#  'tracey delong',
#  'wen tracy',
#  'pamala williams',
#  'amy lavoll',
#  'shanna via',
#  'sue long',
#  'morela harris',
#  'stacey erickson',
#  'ashley taylor',
#  'katie mcdonald',
#  'kelly ellis',
#  'lori greis',
#  'nicole perkins',
#  'brianna anderson',
#  'deanna prince',
#  'lauren pope',
#  'sandra taylor',
#  'krystal carroll',
#  'jan capps',
#  'melissa pruitt',
#  'jeninne amburgey',
#  'sharon weir',
#  'andrea hathaway',
#  'ciara oliver',
#  'kellie murray',
#  'kate harris',
#  'marisa estrada',
#  'allison coffey',
#  'amber hargis',
#  'ronnee ellithorpe',
#  'shavone white',
#  'barbara hall',
#  'briana south',
#  'latonya mott',
#  'shandra jones',
#  'tracey cassidy',
#  'katie cundy',
#  'julie hill',
#  'mandy cross',
#  'pamela bishop',
#  'deana rothwell',
#  'rachel taylor',
#  'elena harvey',
#  'carmen ladera',
#  'tasha denton',
#  'elizabeth monk',
#  'caisie gray',
#  'rachel buttry',
#  'katie motley',
#  'sarah bowe',
#  'chase davenport',
#  'mandi turner',
#  'elizabeth austin',
#  'amber collins',
#  'kara patterson',
#  'ann-katherine stukenborg',
#  'brannan vanover',
#  'leah fletcher',
#  'joni dantzler',
#  'brooke sanders',
#  'emily york',
#  'quindolyn chalmers',
#  'chrisie brown',
#  'tara herrell',
#  'l curtis',
#  'jamie sanders',
#  'kristy phillips',
#  'tammy simmons',
#  'kaley s. rogers',
#  'renee deason',
#  'natalie kazsuk',
#  'carrie bush',
#  'marcea johnson',
#  'paige blizzard',
#  'peggy conway',
#  'kimberly revis',
#  'tiffani dixon',
#  'kirstin tipton',
#  'jackson',
#  'jennifer huggins',
#  'katie nicholson hemel',
#  'smith',
#  'carolyn kent',
#  'doreen lawton',
#  'kelsie smith',
#  'emily melton',
#  'kerry kaufmann',
#  'cara harrell',
#  'kyndle ray',
#  'cynthia buck',
#  'cassidy brown',
#  'carol lee',
#  'kassi knight',
#  'sandra hoyos',
#  "d'anitra reynolds",
#  'mason vaughn',
#  'sommer bauer',
#  'christy ford',
#  'kimberly erickson',
#  'solomon',
#  'katie powers',
#  'kim bounds',
#  'jane kleinhans',
#  'sherry s. wilson',
#  'susie moler',
#  'cathy walter',
#  'colleen drennen',
#  'jennifer barrett',
#  'heather crawford',
#  'robert brodsky',
#  'erin taylor',
#  'pamela rigby',
#  'laurie brown',
#  'lori wilson',
#  's barnett',
#  'meghan cao',
#  'maria e. vives-rodriguez',
#  'sherry snodgrass',
#  'sonya reed',
#  'candice padilla',
#  'misty ball',
#  'marchelle lark',
#  'kristen mcguire',
#  'raeann brink',
#  'stephanie boyce',
#  'melanie cook',
#  'hannah damico',
#  'krystal kochans',
#  'quineisha pittman',
#  'lucia ramos',
#  'kati hundley',
#  'terri tester',
#  'becky jamison',
#  'rhogan',
#  'laura magee',
#  'jill hammon',
#  'jessica clark',
#  'amy garrett',
#  'devon daulton',
#  'beth beason',
#  'tamika jones',
#  'terrell',
#  'angie haney',
#  'susan cook',
#  'brandi ogle',
#  'erin fair',
#  'gisele narcum',
#  'heather bradburn',
#  'alycia snowden',
#  'shawn newport',
#  'johnsie pippin',
#  'savannah verdi',
#  'janeth cruz',
#  'diane kincade',
#  'sandy whetmore',
#  'brooke harrell',
#  'pamela harris',
#  'katie gunn',
#  'kathleen dickerson',
#  'rachel williams',
#  'megan west',
#  'penny woody',
#  'lacey hillard',
#  'robin hamrick',
#  'mallory maharrey',
#  'summer mccolligan',
#  'diana parker',
#  'brandi holland',
#  'demetras cowlie',
#  'teresa winnette',
#  'libby heflen',
#  'makala hooten',
#  'kristie lamb',
#  'autumn morgan',
#  'darcy barton',
#  'brittany mott',
#  'catherine millard-brown',
#  'emma pace',
#  'monique fleming',
#  'cille',
#  'marci hopson',
#  'kellyn robertson',
#  'rachel pace',
#  'misty  ball',
#  'patti randolph',
#  'macy frady',
#  'megan strickland',
#  'dawn crum',
#  'andrea edwards',
#  's meador',
#  'michelle timmons',
#  'shana ward',
#  'michelle harp',
#  'tiereney hunt',
#  'lauren moody',
#  'jessica mcbryar',
#  'esther loudin',
#  'karen olson',
#  'chelsea arment',
#  'tatum winans',
#  'olivia woodall',
#  'summer brown',
#  'christie lauderdale',
#  'krista may',
#  'vondrea davis',
#  'jessica sledge',
#  'brooke beck',
#  'janet thurman',
#  'brittney',
#  'katie wood',
#  'geronetta griffith',
#  'sandi koeshall',
#  'whitney d delaney',
#  'carolyn kent hall',
#  'valerie pulk',
#  'angela golebiewski',
#  'valisa small',
#  'claire mcnatt',
#  'amanda tucker',
#  'rachel koonce',
#  'nicole dolan',
#  'amy houk',
#  'dena acres',
#  'maggie wheeler',
#  'n. sanders',
#  'misty waddell',
#  'ashley papineau',
#  'lisa bukeavich',
#  'carmen martinez',
#  'chelsea  arment',
#  'krystal prater',
#  'diane sirko kincade',
#  'susan frisbee',
#  'leanne nabors',
#  'heather wright',
#  'sara cowan',
#  'stephanie isbill',
#  'krystal gilreath',
#  'baili blankenship',
#  'kirsti nordstrom',
#  'madyson mackenzie',
#  'carol matherly',
#  'riley williamson',
#  'tracy linderman',
#  'lucas tosh',
#  'burton',
#  'lexie doan',
#  'mandy kellar',
#  'lindsay harned',
#  'nawras mahdy',
#  'hillary locke',
#  'catherine wilson',
#  'sarah speed',
#  'l meador',
#  'charlie dugger',
#  'judy bentley',
#  'laura-anne smith',
#  'renika rodgers',
#  'linda gail dandridge',
#  'elizabeth parker',
#  'mallory cox',
#  'amy waters',
#  'leanne rice',
#  'julie niblett',
#  'jessica cardenas',
#  'maria hartsell',
#  'brianna hill',
#  'kia lasley',
#  'taylor nix',
#  'kwanzaa dowell',
#  'britin julian',
#  'chastity crowe',
#  'sara morgan',
#  'lexi marshall',
#  'lisa tyrrell',
#  'ellen ludwig',
#  'lydia barry',
#  'christy rickman',
#  'lexi gildersleeve',
#  'carolyn hall',
#  'kelly stojsavlevich',
#  'kathy bryant',
#  'leanne widmer',
#  'megan troutt',
#  'stephanie rodriguez',
#  'katherine tackett',
#  'diane brewington',
#  'vadia gross',
#  'jennifer roddy',
#  'jessica diffin',
#  'stephanie neas',
#  'patricia clifton',
#  'katie akers',
#  'brooke hickman',
#  'amanda royston',
#  'katelyn robinson',
#  'linda moon',
#  'cathy wilson',
#  'catherine millard',
#  'aj cowan',
#  'kim cooper',
#  'heidi catron',
#  'carolyn norfleet',
#  'deb oglesby',
#  'katlyn mcmillan',
#  'kelly gunter',
#  'laura harris',
#  'lisa manis',
#  'jesus rubio',
#  'tricia diambra',
#  'stacy hartmann',
#  'andrea smith',
#  'trac wilber',
#  'olivia j woodall',
#  'katie flowers',
#  'katelyn taylor',
#  'rachel watson',
#  'emma townsend',
#  'myra williams',
#  'caroline crawford',
#  'pam harris',
#  'jeanene taylor',
#  'kim dean',
#  'penny d woody',
#  'judy herron',
#  'clayton d rouse',
#  'alexzander price',
#  'elizabeth b monk',
#  'kimberly harris',
#  'traci  wilber',
#  'katia reed',
#  'r',
#  'alexa  marshall',
#  'jamie mcghee',
#  'dawn plymouth',
#  'brittany robledo',
#  'joy ann burks',
#  'tamm simmons',
#  'linda gafford',
#  'victoria burnside',
#  'rebeca araya',
#  'latonya k mott',
#  'latonya',
#  'lara hunter',
#  'jody cheek',
#  'amanda cade',
#  'delongtracey',
#  'elizabeth porter',
#  'kim m wiggns',
#  'brand m ogle',
#  'alyson clancy',
#  'makayla king',
#  'd',
#  'angela turner',
#  'gisele  narcum',
#  'betty curtis',
#  'jaycie cupp',
#  'sherry roberts',
#  'alexa marshall',
#  'chrisie  brown',
#  'r hogan',
#  'mason hayes',
#  'candy templin',
#  'katie  motley',
#  'joetta stansberry',
#  'kathryn wood',
#  'emily thais',
#  'kaitlyn wright',
#  'mallory west',
#  'stephanie vasquez',
#  'angela slater',
#  'tammy simmonss',
#  'b. kammerzell',
#  'delores hall',
#  'kenya cervetti',
#  'sandra d hoyos',
#  'carrie',
#  'amy stiles',
#  'anna metaxas',
#  'becky keeton',
#  'b kammerzell',
#  'malllory sigler',
#  'deidra love',
#  'susie coyle',
#  'lexi g',
#  'molly morirs',
#  'natalie',
#  'hannah buck',
#  'sarah wilson',
#  'collee drennen',
#  'darla nightingale',
#  'lexi',
#  'rachel stewar',
#  'haley poole',
#  'michel valadie',
#  'melissa hart wagner',
#  'vaughn',
#  'dana bolton',
#  'burton abby',
#  'tammy  simmons',
#  'katie hemel',
#  'katie mcdonal',
#  'kimberly cooper',
#  'barbara hal',
#  'kristen gilmartin talamao',
#  'clayton rous',
#  'lisa m. frieson',
#  'karen tate',
#  'karen julan',
#  'adaptive',
#  'camille conner',
#  'joy a burks',
#  'wanda marchhie',
#  'angel earl1',
#  'stephanie cowan',
#  'tammmy simmons',
#  'traci wiber',
#  'shawnna carpenter',
#  'alexa gildersleeve',
#  'miranda denham',
#  'amy garret2',
#  'mary fabian',
#  'jessica balderson',
#  'jen johnso',
#  'alison clougherty',
#  'susan holton',
#  'shanda bearden',
#  'jessica picado cardenas',
#  's',
#  'traci wiilber']

# %%
#creating a column to indicate whether or not a name is changed (Y=Yes, N=No); this block contributed by instructor Chris Wright
aeps['changed'] = 'N'

#Building a for loop that compares the entries in the examiner column to the entries in our list
for name in examiner_list:
    
        for ind, row in aeps.iterrows():
            #For any row that indicates it has NOT be changed, the following happens
            if row.changed == 'N':
                #Create a ration of how similar the entry in the dataframe is to the entry in the list
                ratio = fuzz.token_set_ratio(name, row.examiner)
                #For any entries that have a ratio of 100, meaning they match exactly...
                if ratio == 100:
                    #Go ahead and mark the 'changed' column as Y so that row won't be looked at again
                    aeps.loc[ind, 'changed'] = 'Y'
                #For  any entries that are very similar (ratio > 88) but not exactly the same...
                if ((ratio > 88)  & (ratio < 100)):
                    #go ahead and change the entry in the dataframe to match the entry in the list
                    aeps.loc[ind, 'examiner'] = name
                    #and mark the 'changed' column as Y so that row won't be evaluated again
                    aeps.loc[ind, 'changed'] = 'Y'
#This loop continues until all rows are changed or have no match that creates a ratio greater than 88

# %%
#Take a look at how many unique values remain
aeps.examiner.nunique()
# Out:
# 556

# %%
#look at how many rows were marked Y and N after running our loop
aeps['changed'].value_counts()
# Out:
# Y    17725
# N       37
# Name: changed, dtype: int64

# %%
#look at the updated value counts for Examiner names
aeps.examiner.value_counts()
# Out:
# jen johnson                 562
# karen julian                329
# janet dixon                 298
# kristen gilmartin talamo    241
# michele valadie             236
#                            ...
# gisele                        1
# amy j trent                   1
# candace peacock               1
# kaley rogers                  1
# morgan haas                   1
# Name: examiner, Length: 556, dtype: int64

# %%
#Get rid of our 'changed' column now that it's served its purpose
aeps = aeps.drop(columns = 'changed')

# %%
#save the cleaned up df to a csv
aeps.to_csv('data/cleaned_AEPS.csv', index = False)

# %%
#read in the new csv to check it, note the warning giving you a heads up about some columns with mixed datatypes
#new = pd.read_csv('../data/cleaned_AEPS.csv')

# %%
#new

# %%
pd.set_option('display.max_rows', None)
print(aeps.examiner.value_counts())
pd.set_option('display.max_rows', 10)
# Out:
# jen johnson                 562
# karen julian                329
# janet dixon                 298
# kristen gilmartin talamo    241
# michele valadie             236
# kandace haag                224
# clayton rouse               199
# hannah vantrease            193
# traci wilber                192
# aimee loeffler              171
# larendi armstrong           143
# david fosbinder             138
# lori boles                  137
# esmeralda                   135
# shannon blakeman            126
# molly morris                125
# ashley cordell              123
# angel early                 116
# marisa borreca              114
# angie mccoy                 110
# laura harrell               106
# teresa motley               106
# camille crawford            102
# gina wilson                 100
# barbara may                  95
# jennifer cavitt              94
# leeann finnegan              94
# hannah hamilton              93
# kristen gilmartin            92
# heather harman                1
# jessica  cardenas             1
# celia johnson                 1
# teresa                        1
# jaymee gouge                  1
# sandra hoyos! ms              1
# stacey                        1
# olivia thomas                 1
# pat reese                     1
# amanda                        1
# sarah larsen                  1
# katie                         1
# katie mcdonal                 1
# amand                         1
# wanda                         1
# kelly stojsavlevich slp       1
# sheridan b conner             1
# pat. reese                    1
# endia v lewis                 1
# v                             1
# elizabeth                     1
# jeanna d mccloud              1
# joy burks                     1
# eli guin                      1
# kelly holt                    1
# rebecca farmer                1
# kaley s.  rogers              1
# sarah                         1
# averi parker                  1
# darcy bar2                    1
# jennifer  cavitt              1
# savannah terrell              1
# molly molly                   1
# kscott                        1
# andrew mcnatt                 1
# brianna                       1
# sonya d reed                  1
# diane sirko                   1
# ariana lee                    1
# stephanie                     1
# whitney delaney               1
# samantha degeer               1
# sheridan conner               1
# shawn  newport                1
# wanda    marchie              1
# lauren                        1
# angela  slater                1
# asher walker                  1
# stephanie boyce m.ed          1
# carolyn                       1
# jeanna mccloud                1
# traci wil                     1
# jessica l mcbryar             1
# gross motor                   1
# jessica beaver                1
# billie jo burnette            1
# jennifer buchanan             1
# kerry b kaufmann              1
# kaley s rogers                1
# gisele                        1
# amy j trent                   1
# candace peacock               1
# kaley rogers                  1
# morgan haas                   1
# Name: examiner, dtype: int64

# %%
chris = pd.read_csv('../TEIS Partner Project/cleaned_AEPS.csv')
# Out:
# /tmp/ipykernel_38946/1909226299.py:1: DtypeWarning: Columns (0,3,279,282,285,288) have mixed types. Specify dtype option on import or set low_memory=False.
#   chris = pd.read_csv('../TEIS Partner Project/cleaned_AEPS.csv')

# %%
chris.shape
# Out:
# (17959, 307)

# %%
pd.set_option('display.max_rows', None)
print(chris.Examiner.value_counts())
pd.set_option('display.max_rows', 10)
# Out:
# Jen Johnson                       552
# Karen Julian                      332
# Janet Dixon                       300
# Kristen Gilmartin Talamo          241
# Michele Valadie                   240
# Kandace Haag                      225
# Clayton Rouse                     199
# Traci Wilber                      192
# Hannah Vantrease                  192
# Aimee Loeffler                    173
# LaRendi Armstrong                 143
# David Fosbinder                   141
# Lori Boles                        137
# esmeralda                         131
# Shannon Blakeman                  127
# Molly Morris                      126
# Ashley Cordell                    122
# Barbara May                       121
# Angel Early                       120
# Marisa Borreca                    114
# Angie McCoy                       110
# Teresa Motley                     107
# Laura Harrell                     107
# Gina Wilson                       101
# LeeAnn Finnegan                    95
# Jennifer Cavitt                    94
# Hannah Hamilton                    92
# Kristen Gilmartin                  92
# Mallory Sigler                     90
# Sarah Dugan                        89
# Amy Trent                          87
# Diana Barrick                      87
# Laura Riddell                      85
# Leslie Throneberry                 84
# Morgan Blake                       84
# Michelle Fox                       83
# Patricia Reese                     82
# Cindy Kennard                      81
# Rachel Stewart                     80
# Rosario Langlois                   78
# Megan Jones                        78
# camille crawford                   77
# Karisha McNeal                     77
# Deanna Stephens                    76
# Jessie Bradley                     76
# Regina Piercy                      75
# Kristina Scott, EI                 73
# Virginia Martino                   72
# Lisa Ketner                        72
# Britney McConnell                  71
# Kourtney Daniels                   71
